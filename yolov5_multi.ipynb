# %%
# %cd yolov5_multi
import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5  2022-11-1 Python-3.9.12 torch-1.12.0 CUDA:0 (NVIDIA RTX A5000, 24564MiB)
# Setup complete  (56 CPUs, 126.6 GB RAM, 283.5/953.3 GB disk)

# %%
import time
from tqdm.notebook import tqdm

# %%
# Train YOLOv55 using pre-trained weights

# !python train.py --img 1280 --batch 16 --epochs 200 --data custom_data.yaml --weights C:\Users\ag82q\Desktop\OD\yolov5_multi\yolov5n.pt --cache
# Out:
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# [Errno 2] No such file or directory: 'runs\\train\\exp3\\labels_correlogram.jpg'
# wandb: Currently logged in as: ashish582 (sirac). Use `wandb login --relogin` to force relogin
# train: weights=C:\Users\ag82q\Desktop\OD\yolov5_multi\yolov5n.pt, cfg=, data=custom_data.yaml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=200, batch_size=16, imgsz=1280, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# YOLOv5  2022-11-1 Python-3.9.12 torch-1.12.0 CUDA:0 (NVIDIA RTX A5000, 24564MiB)
# ...

# %%
# Run test
# !python val.py --weights C:\Users\ag82q\Desktop\OD\yolov5_multi\runs\train\exp\weights\best.pt --data custom_data.yaml --img 1280 --half --task test
# Out:
# val: data=C:\Users\ag82q\Desktop\OD\yolov5_multi\data\custom_data.yaml, weights=['C:\\Users\\ag82q\\Desktop\\OD\\yolov5_multi\\runs\\train\\exp\\weights\\best.pt'], batch_size=32, imgsz=1280, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs\val, name=exp, exist_ok=False, half=True, dnn=False
# YOLOv5  2022-11-1 Python-3.9.12 torch-1.12.0 CUDA:0 (NVIDIA RTX A5000, 24564MiB)
#
# Fusing layers...
# Model summary: 157 layers, 1763224 parameters, 0 gradients, 4.1 GFLOPs
#
# test: Scanning 'C:\Users\ag82q\Desktop\OD\InsDet_multi\test\labels' images and labels...:   0%|          | 0/45 [00:00<?, ?it/s]
# test: Scanning 'C:\Users\ag82q\Desktop\OD\InsDet_multi\test\labels' images and labels...1 found, 0 missing, 0 empty, 0 corrupt:   2%|2         | 1/45 [00:04<03:13,  4.40s/it]
# ...

# %%
# Train YOLOv55 using pre-trained weights

# !python train.py --img 1280 --batch 16 --epochs 200 --data custom_data.yaml --weights C:\Users\ag82q\Desktop\OD\yolov5_multi\yolov5s.pt --cache
# Out:
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# wandb: Currently logged in as: ashish582 (sirac). Use `wandb login --relogin` to force relogin
# train: weights=C:\Users\ag82q\Desktop\OD\yolov5_multi\yolov5s.pt, cfg=, data=custom_data.yaml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=200, batch_size=16, imgsz=1280, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# YOLOv5  2022-11-1 Python-3.9.12 torch-1.12.0 CUDA:0 (NVIDIA RTX A5000, 24564MiB)
#
# ...

# %%
# Run test
# !python val.py --weights C:\Users\ag82q\Desktop\OD\yolov5_multi\runs\train\exp2\weights\best.pt --data custom_data.yaml --img 1280 --half --task test
# Out:
# val: data=C:\Users\ag82q\Desktop\OD\yolov5_multi\data\custom_data.yaml, weights=['C:\\Users\\ag82q\\Desktop\\OD\\yolov5_multi\\runs\\train\\exp2\\weights\\best.pt'], batch_size=32, imgsz=1280, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs\val, name=exp, exist_ok=False, half=True, dnn=False
# YOLOv5  2022-11-1 Python-3.9.12 torch-1.12.0 CUDA:0 (NVIDIA RTX A5000, 24564MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
#
# test: Scanning 'C:\Users\ag82q\Desktop\OD\InsDet_multi\test\labels.cache' images and labels... 45 found, 0 missing, 0 empty, 0 corrupt: 100%|##########| 45/45 [00:00<?, ?it/s]
# test: Scanning 'C:\Users\ag82q\Desktop\OD\InsDet_multi\test\labels.cache' images and labels... 45 found, 0 missing, 0 empty, 0 corrupt: 100%|##########| 45/45 [00:00<?, ?it/s]
#
# ...

# %%
# Train YOLOv55 using pre-trained weights

# !python train.py --img 1280 --batch 16 --epochs 200 --data custom_data.yaml --weights C:\Users\ag82q\Desktop\OD\yolov5_multi\yolov5m.pt --cache
# Out:
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# wandb: Currently logged in as: ashish582 (sirac). Use `wandb login --relogin` to force relogin
# train: weights=C:\Users\ag82q\Desktop\OD\yolov5_multi\yolov5m.pt, cfg=, data=custom_data.yaml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=200, batch_size=16, imgsz=1280, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# YOLOv5  2022-11-1 Python-3.9.12 torch-1.12.0 CUDA:0 (NVIDIA RTX A5000, 24564MiB)
#
# ...

# %%
# Run test
# !python val.py --weights C:\Users\ag82q\Desktop\OD\yolov5_multi\runs\train\exp3\weights\best.pt --data custom_data.yaml --img 1280 --half --task test
# Out:
# val: data=C:\Users\ag82q\Desktop\OD\yolov5_multi\data\custom_data.yaml, weights=['C:\\Users\\ag82q\\Desktop\\OD\\yolov5_multi\\runs\\train\\exp3\\weights\\best.pt'], batch_size=32, imgsz=1280, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs\val, name=exp, exist_ok=False, half=True, dnn=False
# YOLOv5  2022-11-1 Python-3.9.12 torch-1.12.0 CUDA:0 (NVIDIA RTX A5000, 24564MiB)
#
# Fusing layers...
# Model summary: 212 layers, 20861016 parameters, 0 gradients, 47.9 GFLOPs
#
# test: Scanning 'C:\Users\ag82q\Desktop\OD\InsDet_multi\test\labels.cache' images and labels... 45 found, 0 missing, 0 empty, 0 corrupt: 100%|##########| 45/45 [00:00<?, ?it/s]
# test: Scanning 'C:\Users\ag82q\Desktop\OD\InsDet_multi\test\labels.cache' images and labels... 45 found, 0 missing, 0 empty, 0 corrupt: 100%|##########| 45/45 [00:00<?, ?it/s]
#
# ...

# %%
# Train YOLOv55 using pre-trained weights

# !python train.py --img 1280 --batch 16 --epochs 200 --data custom_data.yaml --weights C:\Users\ag82q\Desktop\OD\yolov5_multi\yolov5l.pt --cache
# Out:
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# wandb: Currently logged in as: ashish582 (sirac). Use `wandb login --relogin` to force relogin
# train: weights=C:\Users\ag82q\Desktop\OD\yolov5_multi\yolov5l.pt, cfg=, data=custom_data.yaml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=200, batch_size=16, imgsz=1280, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# YOLOv5  2022-11-1 Python-3.9.12 torch-1.12.0 CUDA:0 (NVIDIA RTX A5000, 24564MiB)
#
# ...

# %%
# Run test
# !python val.py --weights C:\Users\ag82q\Desktop\OD\yolov5_multi\runs\train\exp4\weights\best.pt --data custom_data.yaml --img 1280 --half --task test
# Out:
# val: data=C:\Users\ag82q\Desktop\OD\yolov5_multi\data\custom_data.yaml, weights=['C:\\Users\\ag82q\\Desktop\\OD\\yolov5_multi\\runs\\train\\exp4\\weights\\best.pt'], batch_size=32, imgsz=1280, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs\val, name=exp, exist_ok=False, half=True, dnn=False
# YOLOv5  2022-11-1 Python-3.9.12 torch-1.12.0 CUDA:0 (NVIDIA RTX A5000, 24564MiB)
#
# Fusing layers...
# Model summary: 267 layers, 46119048 parameters, 0 gradients, 107.7 GFLOPs
#
# test: Scanning 'C:\Users\ag82q\Desktop\OD\InsDet_multi\test\labels.cache' images and labels... 45 found, 0 missing, 0 empty, 0 corrupt: 100%|##########| 45/45 [00:00<?, ?it/s]
# test: Scanning 'C:\Users\ag82q\Desktop\OD\InsDet_multi\test\labels.cache' images and labels... 45 found, 0 missing, 0 empty, 0 corrupt: 100%|##########| 45/45 [00:00<?, ?it/s]
#
# ...

# %%
# Train YOLOv55 using customized weights
#!python train.py --img 1280 --batch 16 --epochs 100 --data custom_data.yaml --weights C:\Users\ag82q\Desktop\OD\yolov5\runs\train\exp\weights\last.pt --cache

# %%
# Make inference
# !python detect.py --weights C:\Users\ag82q\Desktop\OD\yolov5_multi\runs\train\exp4\weights\best.pt --img 1280 --source C:\Users\ag82q\Desktop\OD\InsDet_multi\test\images\Photo-Oct-27--2-09-33-PM_jpg.rf.b88fa9fda21bd629abaeb1337baf1813.jpg
# Out:
# detect: weights=['C:\\Users\\ag82q\\Desktop\\OD\\yolov5_multi\\runs\\train\\exp4\\weights\\best.pt'], source=C:\Users\ag82q\Desktop\OD\InsDet_multi\test\images\Photo-Oct-27--2-09-33-PM_jpg.rf.b88fa9fda21bd629abaeb1337baf1813.jpg, data=data\coco128.yaml, imgsz=[1280, 1280], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  2022-11-1 Python-3.9.12 torch-1.12.0 CUDA:0 (NVIDIA RTX A5000, 24564MiB)
#
# Fusing layers...
# Model summary: 267 layers, 46119048 parameters, 0 gradients, 107.7 GFLOPs
# image 1/1 C:\Users\ag82q\Desktop\OD\InsDet_multi\test\images\Photo-Oct-27--2-09-33-PM_jpg.rf.b88fa9fda21bd629abaeb1337baf1813.jpg: 960x1280 8 CRWBs, 14 Flys, 11 Other-beetles, 20.4ms
# ...

# %%
# Out:
# val: data=C:\Users\ag82q\Desktop\OD\yolov5\data\custom_data.yaml, weights=['C:\\Users\\ag82q\\Desktop\\OD\\yolov5\\runs\\train\\exp2\\weights\\last.pt'], batch_size=32, imgsz=1280, conf_thres=0.001, iou_thres=0.25, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs\val, name=exp, exist_ok=False, half=True, dnn=False
# YOLOv5  2022-11-1 Python-3.9.12 torch-1.12.0 CUDA:0 (NVIDIA RTX A5000, 24564MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
#
# test: Scanning 'C:\Users\ag82q\Desktop\OD\Updated_Data\test\labels' images and labels...:   0%|          | 0/45 [00:00<?, ?it/s]
# test: Scanning 'C:\Users\ag82q\Desktop\OD\Updated_Data\test\labels' images and labels...1 found, 0 missing, 0 empty, 0 corrupt:   2%|2         | 1/45 [00:04<03:17,  4.49s/it]
# ...
